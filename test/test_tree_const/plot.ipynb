# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data3 = pd.read_csv("result_0/configration.csv")
fig3 = plt.figure(figsize=(10,8))
ax3 = fig3.add_subplot()
ax3.plot(data3["t"], data3["x0"], label="x0")
ax3.plot(data3["t"], data3["x1"], label="x1")
ax3.plot(data3["t"], data3["x2"], label="x2")
ax3.plot(data3["t"], data3["x3"], label="x3")
ax3.legend()
ax3.grid()

# %%
data3 = pd.read_csv("result_0/configration.csv")
fig3 = plt.figure(figsize=(10,8))
ax3 = fig3.add_subplot()
ax3.plot(data3["t"], data3["x0"], label="x0")
ax3.plot(data3["t"], data3["x1"], label="x1")
ax3.plot(data3["t"], data3["x2"], label="x2")
ax3.plot(data3["t"], data3["x3"], label="x3")
ax3.legend()
ax3.grid()

# %%
data3 = pd.read_csv("result/configration.csv")
fig3 = plt.figure(figsize=(10,8))
ax3 = fig3.add_subplot()
ax3.plot(data3["t"], data3["x0"], label="x0")
ax3.plot(data3["t"], data3["x1"], label="x1")
ax3.plot(data3["t"], data3["x2"], label="x2")
ax3.plot(data3["t"], data3["x3"], label="x3")
ax3.legend()
ax3.grid()

# %%
data3 = pd.read_csv("result/configration.csv")
fig3 = plt.figure(figsize=(10,8))
ax3 = fig3.add_subplot()
ax3.plot(data3["t"], data3["x0"], label="x0")
ax3.plot(data3["t"], data3["x1"], label="x1")
ax3.plot(data3["t"], data3["x2"], label="x2")
ax3.plot(data3["t"], data3["x3"], label="x3")
ax3.legend()
ax3.grid()
